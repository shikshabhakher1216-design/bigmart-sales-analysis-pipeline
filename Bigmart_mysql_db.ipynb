# %%
# install library to connect python with mysql
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# import the basic packages
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings(action = "ignore")

# %%
# import mysql connector for the connection
import mysql.connector

# %%
conn = mysql.connector.connect(
    # create connection to mysql database
    
    host="localhost",
    # database is on local machine
    
    user="root",
    # mysql username
    
    password="Shiksha@1017",
    # mysql password
    
    database="big_mart"
    # database name to connect
    
    )

# %%
query = "select * from cleaned_bigmart ;"
# sql query to get all data from the table

# %%
df = pd.read_sql(query, conn)
# load data from mysql into a pandas dataFrame

# here, query tells what data to fetch from mysql, and conn tells from where to fetch the data

# %%
# view
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.066132  Fruits and Vegetables
# 4         8.93          Low Fat         0.066132              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Outlet_Age
# ...

# %%
# building model, seperating x and y

x = df.drop("Item_Outlet_Sales", axis = 1)

y = df.Item_Outlet_Sales

# %%
# verify
x[:1]
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility Item_Type  Item_MRP  \
# 0          9.3          Low Fat         0.016047     Dairy  249.8092
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
#
#          Outlet_Type  Outlet_Age
# 0  Supermarket Type1          25

# %%
# shape of x
x.shape
# Out:
# (8523, 10)

# %%
# and
y[:1]
# Out:
# 0    3735.138
# Name: Item_Outlet_Sales, dtype: float64

# %%
# shape of y
y.shape
# Out:
# (8523,)

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
x[:2]
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
#
#    Outlet_Age  Item_Fat_Content_Regular  Item_Type_Breads  \
# 0          25                     False             False
# 1          15                      True             False
#
#    Item_Type_Breakfast  Item_Type_Canned  Item_Type_Dairy  ...  \
# 0                False             False             True  ...
# 1                False             False            False  ...
#
#    Item_Type_Snack Foods  Item_Type_Soft Drinks  Item_Type_Starchy Foods  \
# 0                  False                  False                    False
# 1                  False                   True                    False
#
#    Outlet_Size_Medium  Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# 0                True              False                        False
# ...

# %%
# checking shape
x.shape
# Out:
# (8523, 28)

# %%
# checking data type
x.dtypes
# Out:
# Item_Weight                        float64
# Item_Visibility                    float64
# Item_MRP                           float64
# Outlet_Establishment_Year            int64
# Outlet_Age                           int64
# Item_Fat_Content_Regular              bool
# Item_Type_Breads                      bool
# Item_Type_Breakfast                   bool
# Item_Type_Canned                      bool
# Item_Type_Dairy                       bool
# Item_Type_Frozen Foods                bool
# Item_Type_Fruits and Vegetables       bool
# Item_Type_Hard Drinks                 bool
# Item_Type_Health and Hygiene          bool
# Item_Type_Household                   bool
# Item_Type_Meat                        bool
# Item_Type_Others                      bool
# Item_Type_Seafood                     bool
# Item_Type_Snack Foods                 bool
# Item_Type_Soft Drinks                 bool
# Item_Type_Starchy Foods               bool
# Outlet_Size_Medium                    bool
# ...

# %%
# checking data type of y
y.dtypes
# Out:
# dtype('float64')

# %%
# train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((6818, 28), (1705, 28), (6818,), (1705,))

# %%
# model building
from sklearn.linear_model import LinearRegression

# %%
# call and assign
lr = LinearRegression()

# %%
# fit the model
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# train accuracy
lr.score(x_train, y_train)
# Out:
# 0.5642043052818086

# %%
# test accuracy
lr.score(x_test, y_test)
# Out:
# 0.558227347421568

# %%
# prediction
y_pred = lr.predict(x_test)

# %%
# view
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.066132  Fruits and Vegetables
# 4         8.93          Low Fat         0.066132              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Outlet_Age
# ...

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# ----- Evaluation -----
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.558227347421568

# %%
# scaling the data
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train_scaled,y_train)
# Out:
# 0.5642043052818086

# %%
lr.score(x_test_scaled,y_test)
# Out:
# 0.5582273474215678

# %%
# dataset
x
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.066132  182.0950                       1998
# 4           8.930         0.066132   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Outlet_Age  Item_Fat_Content_Regular  Item_Type_Breads  \
# ...

# %%
# Scaling does not improve the accuracy
# use regularization models

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
ridge.score(x_train,y_train)
# Out:
# 0.5641844161043208

# %%
ridge.score(x_test,y_test)
# Out:
# 0.5582239503012589

# %%
ridge.fit(x_train_scaled,y_train)
# Out:
# Ridge()

# %%
ridge.score(x_train_scaled,y_train)
# Out:
# 0.5642036888829991

# %%
ridge.score(x_test_scaled,y_test)
# Out:
# 0.5582200751731632

# %%
y_pred = ridge.predict(x_test_scaled)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5582200751731632

# %%
ridge = Ridge(alpha=0.01)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.01)

# %%
ridge.score(x_train,y_train)
# Out:
# 0.564204302660076

# %%
ridge.score(x_test,y_test)
# Out:
# 0.5582273188861011

# %%
ridge.fit(x_train_scaled,y_train)
# Out:
# Ridge(alpha=0.01)

# %%
ridge.score(x_test_scaled,y_test)
# Out:
# 0.5582272720224019

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso()

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
lasso.score(x_train,y_train)
# Out:
# 0.5636346729691414

# %%
lasso.score(x_test,y_test)
# Out:
# 0.5584950742726881

# %%
lasso.fit(x_train_scaled,y_train)
# Out:
# Lasso()

# %%
lasso.score(x_train_scaled,y_train)
# Out:
# 0.563929414215627

# %%
lasso.score(x_test_scaled,y_test)
# Out:
# 0.5578577680328093

# %%
lasso =Lasso(alpha=0.01)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.01)

# %%
lasso.score(x_train,y_train)
# Out:
# 0.5642041733156271

# %%
lasso.score(x_test,y_test)
# Out:
# 0.5582311523759288

# %%
lasso.fit(x_train_scaled,y_train)
# Out:
# Lasso(alpha=0.01)

# %%
lasso.score(x_train_scaled,y_train)
# Out:
# 0.564204268572414

# %%
lasso.score(x_test_scaled,y_test)
# Out:
# 0.5582255976120813

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# There is no change in accuracy so using XGBOOST Regressor

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)

# %%
# model building
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(n_estimators=200, learning_rate=0.05, max_depth=4, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.3, reg_lambda=1, random_state=42)

# %%
# fit the model
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# train accuracy
xgb.score(x_train, y_train)
# Out:
# 0.6622669642497381

# %%
# test accuracy
xgb.score(x_test, y_test)
# Out:
# 0.5838525469530165

# %%
# prediction
y_pred = xgb.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.5838525469530165

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 779.8924102076601

# %%
# now, push full data to mysql

# %%
from sqlalchemy import create_engine
# is used to connect python with the database and transfer data

# %%
engine = create_engine(
    "mysql+mysqlconnector://<root_name>:<YOUR_MYSQL_PASSWORD>@localhost/big_mart"
)

# %%
# at first, create connection engine
# then use mysql with mysqlconnector driver and provide username, password, host (local machine), database name

# %%
# df.to_sql("cleaned_bigmart", con = engine, if_exists = 'replace', index = False)

# %%
engine.connect()

# %%
# alternative, if we don’t want to replace
df.to_sql("bigmart_with_predictions", con = engine, if_exists = 'replace', index = False)
# Out:
# 8523

# %%
# send dataframe to mysql, name of the table to create / store data, use database connection, 

# replace table if it already exists,  do not store dataframe index as column

# %%
# custom predictions: hold
